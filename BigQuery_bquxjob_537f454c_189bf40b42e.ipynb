# %% [markdown]
# <a href="https://colab.research.google.com/github/jawahar-p/myfirstproject/blob/main/BigQuery_bquxjob_537f454c_189bf40b42e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'mg-motors-bigq' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=mg-motors-bigq:US:bquxjob_537f454c_189bf40b42e)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_766c3a84_189bfb941c1') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT
#   user_pseudo_id,
#   IFNULL(TIMESTAMP_DIFF(Complete, Start, MICROSECOND)/1000000, 0) AS Loading_time,
#   IFNULL(TIMESTAMP_DIFF(Microinteraction, Start, MICROSECOND)/1000000, 0) AS Microinteraction_time,
#   IFNULL(TIMESTAMP_DIFF(Interior, Start, MICROSECOND)/1000000, 0) AS Interior_time,
#   IFNULL(TIMESTAMP_DIFF(Audio_Feature, Start, MICROSECOND)/1000000, 0) AS Audio_Feature_time,
#   IFNULL(TIMESTAMP_DIFF(Variants, Start, MICROSECOND)/1000000, 0) AS Variants_time,
#   IFNULL(TIMESTAMP_DIFF(Accessorize, Start, MICROSECOND)/1000000, 0) AS Accessorize_time,
#   IFNULL(TIMESTAMP_DIFF(Summary, Start, MICROSECOND)/1000000, 0) AS Summary_time,
#   IFNULL(TIMESTAMP_DIFF(Concierge, Start, MICROSECOND)/1000000, 0) AS Concierge_time,
# FROM (
#   SELECT
#     user_pseudo_id,
#     month,
#     MIN(CASE WHEN 'start' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Start,
#     MIN(CASE WHEN 'end' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Complete,
#     MIN(CASE WHEN event_name = 'micro' THEN timestamp_micros(event_timestamp) END) AS Microinteraction,
#     MIN(CASE WHEN 'int' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'Feature_Menu_1') THEN timestamp_micros(event_timestamp) END) AS Interior,
#     MIN(CASE WHEN 'audio' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'Feature_Menu_1') THEN timestamp_micros(event_timestamp) END) AS Audio_Feature,
#     MIN(CASE WHEN 'variants' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Variants,
#     MIN(CASE WHEN 'accessorize' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Accessorize,
#     MIN(CASE WHEN 'summary' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Summary,
#     MIN(CASE WHEN event_name = 'pulsehub icon' AND 'click' IN (SELECT value.string_value FROM UNNEST(event_params) WHERE key = 'click') THEN timestamp_micros(event_timestamp) END) AS Concierge
#   FROM (
#     SELECT user_pseudo_id, event_name, event_params, event_timestamp, SUBSTR(event_date, 5, 2) AS month
#     FROM `mg-motors-bigq.analytics_355525355.events_202307*`, UNNEST(event_params)
#     WHERE key = 'ga_session_number' AND value.int_value = 1
#   ) AS filtered_data
#   --WHERE user_pseudo_id = '1036243331.1690967896'
#   GROUP BY user_pseudo_id, month
# );
#
# --Limitation
# --High accuracy for users with only one session in the given time period.
# --Able to calculate only the mininum time interval, still there will some concern.

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_766c3a84_189bfb941c1') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
#              user_pseudo_id  Loading_time  Microinteraction_time  \
# 0      676579097.1690027813      0.000000               0.000000
# 1     2123338831.1690039674    151.883353             194.334213
# 2      183881664.1689160565      0.000000               0.000000
# 3      980398115.1690013523      0.000000               0.000000
# 4     1920413370.1690013538      0.000000               0.000000
# ...                     ...           ...                    ...
# 3889   868377750.1689489017      0.000000               0.000000
# 3890   243296997.1689476525      0.000000               0.000000
# 3891  1422904802.1675705319      0.000000               0.000000
# 3892   561233415.1687019704      5.046837              14.743744
# 3893   505099622.1689526054     17.146792             102.292037
#
#       Interior_time  Audio_Feature_time  Variants_time  Accessorize_time  \
# 0               0.0                 0.0       0.000000          0.000000
# 1               0.0                 0.0       0.000000          0.000000
# 2               0.0                 0.0       0.000000          0.000000
# 3               0.0                 0.0       0.000000          0.000000
# 4               0.0                 0.0       0.000000          0.000000
# ...             ...                 ...            ...               ...
# 3889            0.0                 0.0       0.000000          0.000000
# 3890            0.0                 0.0       3.530640         45.341258
# 3891            0.0                 0.0       0.000000          0.000000
# 3892            0.0                 0.0       0.000000          0.000000
# 3893            0.0                 0.0     186.960674          0.000000
#
#       Summary_time  Concierge_time
# 0         0.000000        0.000000
# 1       497.040786      455.398989
# 2         0.000000        0.000000
# 3         0.000000        0.000000
# 4         0.000000        0.000000
# ...            ...             ...
# 3889      0.000000        0.000000
# 3890      0.000000        0.000000
# 3891      0.000000        0.000000
# 3892      0.000000        0.000000
# 3893      0.000000        0.000000
#
# [3894 rows x 9 columns]

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
# Out:
#        Loading_time  Microinteraction_time  Interior_time  Audio_Feature_time  \
# count   3894.000000            3894.000000         3894.0         3894.000000
# mean       8.471767              28.512896            0.0            2.286461
# std       47.091798             104.580158            0.0           44.880786
# min     -109.510061             -27.626942            0.0            0.000000
# 25%        0.000000               0.000000            0.0            0.000000
# 50%        0.000000               0.000000            0.0            0.000000
# 75%        9.844409              18.314689            0.0            0.000000
# max     2591.525317            1891.903119            0.0         1878.737926
#
#        Variants_time  Accessorize_time  Summary_time  Concierge_time
# count    3894.000000       3894.000000   3894.000000     3894.000000
# mean       17.999261         15.981301     10.367858        9.039656
# std        75.765423         69.884239     76.860224       69.163525
# min         0.000000          0.000000      0.000000        0.000000
# 25%         0.000000          0.000000      0.000000        0.000000
# 50%         0.000000          0.000000      0.000000        0.000000
# 75%         0.000000          0.000000      0.000000        0.000000
# max      1907.527690       1554.728539   2490.399141     1893.322125

# %%
results['Loading_time'].sort_values(ascending = True)
# Out:
# 1930    -109.510061
# 1923     -40.889937
# 86       -14.159814
# 2185     -13.000128
# 3837     -11.479467
#            ...
# 3450     368.074885
# 3258     379.466886
# 3317     416.446579
# 2881     590.970546
# 3413    2591.525317
# Name: Loading_time, Length: 3894, dtype: float64

# %%
pos_loading = results[results['Loading_time']>0]
pos_loading
# Out:
#              user_pseudo_id  Loading_time  Microinteraction_time  \
# 1     2123338831.1690039674    151.883353             194.334213
# 5     1431924920.1690013542     16.429292              19.935471
# 9     1034932205.1690038952      5.776946               5.776946
# 10     577684970.1689966632      6.325713              69.575662
# 13    1269123815.1690028075      5.429909               0.000000
# ...                     ...           ...                    ...
# 3875  1562504917.1688116864     14.553138              61.440130
# 3884   278236878.1689517862      7.247689              30.842927
# 3888  1299753749.1689397580     21.434198               0.000000
# 3892   561233415.1687019704      5.046837              14.743744
# 3893   505099622.1689526054     17.146792             102.292037
#
#       Interior_time  Audio_Feature_time  Variants_time  Accessorize_time  \
# 1               0.0                 0.0       0.000000          0.000000
# 5               0.0                 0.0       0.000000          0.000000
# 9               0.0                 0.0       0.000000          0.000000
# 10              0.0                 0.0     215.208010          0.000000
# 13              0.0                 0.0       0.000000          0.000000
# ...             ...                 ...            ...               ...
# 3875            0.0                 0.0       0.000000          0.000000
# 3884            0.0                 0.0      11.290923        180.547432
# 3888            0.0                 0.0      76.280068         93.683859
# 3892            0.0                 0.0       0.000000          0.000000
# 3893            0.0                 0.0     186.960674          0.000000
#
#       Summary_time  Concierge_time
# 1       497.040786      455.398989
# 5         0.000000        0.000000
# 9        40.700437        0.000000
# 10        0.000000        0.000000
# 13        0.000000        0.000000
# ...            ...             ...
# 3875      0.000000        0.000000
# 3884    200.430718        0.000000
# 3888      0.000000        0.000000
# 3892      0.000000        0.000000
# 3893      0.000000        0.000000
#
# [1584 rows x 9 columns]

# %%
pos_loading.describe()
# Out:
#        Loading_time  Microinteraction_time  Interior_time  Audio_Feature_time  \
# count   1584.000000            1584.000000         1584.0         1584.000000
# mean      20.954846              51.544120            0.0            5.273750
# std       71.985314             133.701527            0.0           69.767113
# min        0.000092               0.000000            0.0            0.000000
# 25%        8.143421               0.000000            0.0            0.000000
# 50%       11.880969              11.493619            0.0            0.000000
# 75%       18.639418              54.411596            0.0            0.000000
# max     2591.525317            1785.430628            0.0         1878.737926
#
#        Variants_time  Accessorize_time  Summary_time  Concierge_time
# count    1584.000000       1584.000000   1584.000000     1584.000000
# mean       35.268689         29.510706     20.673120       18.405885
# std       109.280436         92.071068    114.386569      102.315938
# min         0.000000          0.000000      0.000000        0.000000
# 25%         0.000000          0.000000      0.000000        0.000000
# 50%         0.000000          0.000000      0.000000        0.000000
# 75%        26.683335          0.000000      0.000000        0.000000
# max      1907.527690       1276.449969   2490.399141     1893.322125

# %%
pos_loading['Audio_Feature_time'].sort_values(ascending=True)
# Out:
# 1          0.000000
# 2597       0.000000
# 2594       0.000000
# 2593       0.000000
# 2590       0.000000
#            ...
# 3196     468.812385
# 3339     793.666853
# 568     1010.091215
# 114     1267.618081
# 3301    1878.737926
# Name: Audio_Feature_time, Length: 1584, dtype: float64
